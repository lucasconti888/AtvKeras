# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# %%
# Carregando o dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data"
columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
df = pd.read_csv(url, header=None, names=columns)

# %% [markdown]
# **Número de amostras:** 303
#
#  **Features:**
#
#  13, incluindo idade, sexo, tipo de dor no peito, pressão arterial em repouso, colesterol, nível de açúcar no sangue, eletrocardiograma, frequência cardíaca máxima, angina induzida por exercício, depressão do ST, inclinação do segmento ST, número de vasos principais coloridos por fluoroscopia, e a condição de fluxo sanguíneo.
#
#  **Tarefa de classificação:**
#
# O objetivo é prever a presença de doença cardíaca (target = 1) ou ausência de doença cardíaca (target = 0).
# Desenvolvimento do Modelo em Keras
# Agora, vamos desenvolver o modelo sequencial utilizando Keras.

# %%
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  target
# 0      3.0  0.0  6.0       0
# 1      2.0  3.0  3.0       2
# 2      2.0  2.0  7.0       1
# 3      3.0  0.0  3.0       0
# 4      1.0  0.0  3.0       0
# ..     ...  ...  ...     ...
# 298    2.0  0.0  7.0       1
# 299    2.0  2.0  7.0       2
# 300    2.0  1.0  7.0       3
# 301    2.0  1.0  3.0       1
# 302    1.0    ?  3.0       0
#
# [303 rows x 14 columns]

# %%
# Limpando e preparando os dados
df.replace('?', np.nan, inplace=True)
df.dropna(inplace=True)
df['target'] = df['target'].apply(lambda x: 1 if x > 0 else 0)

# Separando as features e o rótulo
X = df.drop(columns=['target'])
y = df['target']

# Padronizando os dados
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Dividindo em conjunto de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Definindo o modelo
model = Sequential()
model.add(Dense(1, activation='sigmoid', input_shape=(X_train.shape[1],)))

# Compilando o modelo
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])

# Treinando o modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=10, validation_split=0.2, verbose=1)

# Avaliação no conjunto de teste
y_pred = model.predict(X_test)
y_pred_binary = np.round(y_pred)

# Calculando métricas
accuracy = accuracy_score(y_test, y_pred_binary)
f1 = f1_score(y_test, y_pred_binary)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/
50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8434 - auc: 0.8914 - loss: 0.4347 - val_accuracy: 0.5625 - val_auc: 0.6163 - val_loss: 0.7092
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7635 - auc: 0.8249 - loss: 0.5075 - val_accuracy: 0.5625 - val_auc: 0.6233 - val_loss: 0.7040
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8401 - auc: 0.8759 - loss: 0.4383 - val_accuracy: 0.5625 - val_auc: 0.6346 - val_loss: 0.6998
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7578 - auc: 0.8217 - loss: 0.5158 - val_accuracy: 0.5625 - val_auc: 0.6425 - val_loss: 0.6959
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8018 - auc: 0.8530 - loss: 0.4651 - val_accuracy: 0.5833 - val_auc: 0.6486 - val_loss: 0.6921
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7775 - auc: 0.8522 - loss: 0.4686 - val_accuracy: 0.5833 - val_auc: 0.6521 - val_loss: 0.6888
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8029 - auc: 0.8983 - loss: 0.4223 - val_accuracy: 0.5833 - val_auc: 0.6556 - val_loss: 0.6857
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7531 - auc: 0.8178 - loss: 0.5046 - val_accuracy: 0.5833 - val_auc: 0.6600 - val_loss: 0.6826
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7854 - auc: 0.8376 - loss: 0.5025 - val_accuracy: 0.5833 - val_auc: 0.6617 - val_loss: 0.6797
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7684 - auc: 0.8439 - loss: 0.4955 - val_accuracy: 0.5833 - val_auc: 0.6643 - val_loss: 0.6774
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7905 - auc: 0.8947 - loss: 0.4273 - val_accuracy: 0.5833 - val_auc: 0.6652 - val_loss: 0.6747
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7746 - auc: 0.8806 - loss: 0.4582 - val_accuracy: 0.5833 - val_auc: 0.6643 - val_loss: 0.6723
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7995 - auc: 0.8680 - loss: 0.4510 - val_accuracy: 0.5833 - val_auc: 0.6652 - val_loss: 0.6704
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8262 - auc: 0.9151 - loss: 0.3822 - val_accuracy: 0.5833 - val_auc: 0.6670 - val_loss: 0.6685
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8607 - auc: 0.9316 - loss: 0.3472 - val_accuracy: 0.5833 - val_auc: 0.6774 - val_loss: 0.6674
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7931 - auc: 0.8666 - loss: 0.4619 - val_accuracy: 0.5833 - val_auc: 0.6766 - val_loss: 0.6658
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7876 - auc: 0.8679 - loss: 0.4566 - val_accuracy: 0.6042 - val_auc: 0.6801 - val_loss: 0.6637
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8067 - auc: 0.8933 - loss: 0.4135 - val_accuracy: 0.6042 - val_auc: 0.6818 - val_loss: 0.6625
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7997 - auc: 0.8961 - loss: 0.4318 - val_accuracy: 0.6042 - val_auc: 0.6853 - val_loss: 0.6610
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8316 - auc: 0.9216 - loss: 0.3821 - val_accuracy: 0.6042 - val_auc: 0.6871 - val_loss: 0.6597
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8322 - auc: 0.8936 - loss: 0.4108 - val_accuracy: 0.6042 - val_auc: 0.6897 - val_loss: 0.6587
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8291 - auc: 0.8824 - loss: 0.4188 - val_accuracy: 0.6042 - val_auc: 0.6897 - val_loss: 0.6579
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7578 - auc: 0.8685 - loss: 0.4765 - val_accuracy: 0.6250 - val_auc: 0.6897 - val_loss: 0.6571
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8227 - auc: 0.8922 - loss: 0.4263 - val_accuracy: 0.6250 - val_auc: 0.6906 - val_loss: 0.6561
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8609 - auc: 0.9319 - loss: 0.3496 - val_accuracy: 0.6458 - val_auc: 0.6906 - val_loss: 0.6552
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8405 - auc: 0.9149 - loss: 0.3787 - val_accuracy: 0.6458 - val_auc: 0.6914 - val_loss: 0.6547
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8271 - auc: 0.8877 - loss: 0.4238 - val_accuracy: 0.6458 - val_auc: 0.6949 - val_loss: 0.6543
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8374 - auc: 0.9038 - loss: 0.3937 - val_accuracy: 0.6458 - val_auc: 0.6949 - val_loss: 0.6535
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8486 - auc: 0.9101 - loss: 0.3902 - val_accuracy: 0.6458 - val_auc: 0.7019 - val_loss: 0.6530
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8547 - auc: 0.9196 - loss: 0.3617 - val_accuracy: 0.6458 - val_auc: 0.7045 - val_loss: 0.6532
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7db234ecdcf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# WARNING:tensorflow:6 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7db234ecdcf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
print(f"Acurácia: {accuracy}")
print(f"F1-Score: {f1}")
# Out:
# Acurácia: 0.8333333333333334
# F1-Score: 0.8

# %% [markdown]
# # Explicação dos Componentes
#
# ## Modelo Sequencial e Camada Dense:
#
# O modelo sequencial com uma camada Dense é uma abordagem simples e direta para classificação binária.
#
# ## Função de Ativação Sigmoid:
#
# A ativação sigmoid é usada para gerar uma probabilidade de saída entre 0 e 1.
#
# ## Otimizador Adam:
#
# Adam é um otimizador robusto que ajusta a taxa de aprendizado durante o treinamento, baseado em momentos de gradiente, ajudando o modelo a convergir mais rapidamente e de forma estável.
#
# ## Função de Perda Binary Crossentropy:
#
# A função binary_crossentropy é a escolha ideal para medir a diferença entre as previsões de classe binária e os valores reais.
#
# ## Métricas Accuracy e AUC:
#
# Accuracy mede a proporção de previsões corretas, enquanto a AUC fornece uma visão mais detalhada da capacidade do modelo em discriminar entre as classes.
#
# # Resultados e Interpretação
#
# ## Interpretação:
#
# **Acurácia:** Uma acurácia de 0.83 indica que 83% das previsões do modelo estão corretas. Isso sugere um bom desempenho geral.
#
# **F1 Score:** Um F1 score de 0.8, que é próximo da acurácia, indica um equilíbrio entre precisão e recall, importante para identificar corretamente os casos de doença cardíaca.
#
# ## Possíveis Melhorias:
#
# **Ajuste de Hiperparâmetros:** Testar diferentes configurações para o número de épocas, taxa de aprendizado, e tamanho do batch.
#
# **Camadas Adicionais:** Adicionar mais camadas ou neurônios pode capturar melhor a complexidade dos dados.
#
# **Resampling:** Considerar o balanceamento das classes no conjunto de treinamento para melhorar o desempenho em dados desbalanceados.
#
# Essas melhorias podem ajudar a aumentar a precisão e a capacidade do modelo de identificar corretamente os pacientes com risco de doenças cardíacas.
